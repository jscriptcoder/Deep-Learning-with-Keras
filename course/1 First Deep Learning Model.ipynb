# %% [markdown]
# # First Deep Learning Model

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5,1,'Blue circles and Red crosses')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 0s 181us/step - loss: 0.6975 - acc: 0.6000
# Epoch 2/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.6656 - acc: 0.6530
# Epoch 3/20
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.5950 - acc: 0.8080
# Epoch 4/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.4903 - acc: 0.8650
# Epoch 5/20
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.3927 - acc: 0.8740
# Epoch 6/20
# 1000/1000 [==============================] - 0s 41us/step - loss: 0.3001 - acc: 0.9300
# Epoch 7/20
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.2138 - acc: 0.9910
# Epoch 8/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.1565 - acc: 0.9990
# Epoch 9/20
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1189 - acc: 0.9990
# Epoch 10/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0948 - acc: 0.9990
# Epoch 11/20
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0787 - acc: 0.9990
# Epoch 12/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0670 - acc: 0.9990
# Epoch 13/20
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.0584 - acc: 0.9990
# Epoch 14/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0518 - acc: 0.9990
# Epoch 15/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0464 - acc: 0.9990
# Epoch 16/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0422 - acc: 0.9990
# Epoch 17/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0387 - acc: 0.9990
# Epoch 18/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0358 - acc: 0.9990
# Epoch 19/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0332 - acc: 0.9990
# Epoch 20/20
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0309 - acc: 0.9990

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5,1,'Blue circles and Red crosses')
